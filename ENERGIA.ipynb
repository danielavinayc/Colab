# %% [markdown]
# <a href="https://colab.research.google.com/github/danielavinayc/Colab/blob/main/ENERGIA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://www.tecsaqro.com.mx/blog/companias-electricas-mas-grandes-del-mundo/

# %% [markdown]
# # Brent Crude Oil

# %%
from google.colab import files
import io as io
upload=files.upload()
# Out:
#      <input type="file" id="files-3986037b-cf7c-4362-9544-1d2d73042866" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3986037b-cf7c-4362-9544-1d2d73042866">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd # working with data
import numpy as np # working with arrays
import matplotlib.pyplot as plt # visualization
import seaborn as sb
from sklearn.linear_model import LinearRegression

# %%
D = pd.read_csv('D.csv')

# %%
#REGRESION  

#crear la matriz de características X y la variable objetivo y

X = pd.to_datetime(D['Date']).apply(lambda x: x.toordinal())
y = D['Adj Close']

#ajustar el modelo de regresión lineal

model = LinearRegression()
model.fit(X.values.reshape(-1, 1), y)

#obtener los coeficientes de la regresión

coef = model.coef_
intercept = model.intercept_

#graficar la línea de la regresión junto con los puntos originales del DataFrame

plt.scatter(pd.to_datetime(D['Date']), y)
plt.plot(pd.to_datetime(D['Date']), model.predict(X.values.reshape(-1, 1)), color='red')
plt.xlabel('Date')
plt.ylabel('Adj Close')
plt.title('Regresión lineal D')
plt.show()

# %%
#REGRESION PARTES
#crear los tres subconjuntos del DataFrame

D1 = D.loc[(D['Date'] >= '2018-02-12') & (D['Date'] <= '2020-01-01')]
D2 = D.loc[(D['Date'] > '2020-01-01') & (D['Date'] <= '2022-01-01')]
D3 = D.loc[(D['Date'] > '2022-01-01') & (D['Date'] <= '2023-02-10')]

#crear las matrices de características X y la variable objetivo y para cada subconjunto

X1 = pd.to_datetime(D1['Date']).apply(lambda x: x.toordinal())
X2 = pd.to_datetime(D2['Date']).apply(lambda x: x.toordinal())
X3 = pd.to_datetime(D3['Date']).apply(lambda x: x.toordinal())

y1 = D1['Adj Close']
y2 = D2['Adj Close']
y3 = D3['Adj Close']

#ajustar el modelo de regresión lineal para cada subconjunto

model1 = LinearRegression()
model1.fit(X1.values.reshape(-1, 1), y1)

model2 = LinearRegression()
model2.fit(X2.values.reshape(-1, 1), y2)

model3 = LinearRegression()
model3.fit(X3.values.reshape(-1, 1), y3)

#obtener los coeficientes de cada regresión

coef1 = model1.coef_
intercept1 = model1.intercept_

coef2 = model2.coef_
intercept2 = model2.intercept_

coef3 = model3.coef_
intercept3 = model3.intercept_

#graficar las líneas de regresión junto con los puntos originales del DataFrame para cada subconjunto

plt.scatter(pd.to_datetime(D1['Date']), y1)
plt.plot(pd.to_datetime(D1['Date']), model1.predict(X1.values.reshape(-1, 1)), color='red', label='2018-02-12 to 2020-01-01')

plt.scatter(pd.to_datetime(D2['Date']), y2)
plt.plot(pd.to_datetime(D2['Date']), model2.predict(X2.values.reshape(-1, 1)), color='green', label='2020-01-01 to 2022-01-01')

plt.scatter(pd.to_datetime(D3['Date']), y3)
plt.plot(pd.to_datetime(D3['Date']), model3.predict(X3.values.reshape(-1, 1)), color='blue', label='2022-01-01 to 2023-02-10')

plt.xlabel('Date')
plt.ylabel('Adj Close')
plt.title('Regresión lineal en tres partes de D')
plt.legend()
plt.show()

# %%
D['Date'] = pd.to_datetime(D['Date'])

#Obtener la fecha en la que se alcanzó el valor máximo de Adj Close

max_date = D.loc[D['Adj Close'].idxmax()]['Date']

#Obtener la fecha en la que se alcanzó el valor mínimo de Adj Close

min_date = D.loc[D['Adj Close'].idxmin()]['Date']

print("Fecha de máximo Adj Close:", max_date)
print("Fecha de mínimo Adj Close:", min_date)
# Out:
# Fecha de máximo Adj Close: 2022-04-08 00:00:00
# Fecha de mínimo Adj Close: 2018-06-06 00:00:00

# %% [markdown]
# # Duke

# %%
DUK = pd.read_csv('DUK.csv')

# %%
#REGRESION  

#crear la matriz de características X y la variable objetivo y

X = pd.to_datetime(DUK['Date']).apply(lambda x: x.toordinal())
y = DUK['Adj Close']

#ajustar el modelo de regresión lineal

model = LinearRegression()
model.fit(X.values.reshape(-1, 1), y)

#obtener los coeficientes de la regresión

coef = model.coef_
intercept = model.intercept_

#graficar la línea de la regresión junto con los puntos originales del DataFrame

plt.scatter(pd.to_datetime(DUK['Date']), y)
plt.plot(pd.to_datetime(DUK['Date']), model.predict(X.values.reshape(-1, 1)), color='red')
plt.xlabel('Date')
plt.ylabel('Adj Close')
plt.title('Regresión lineal DUK')
plt.show()

# %%
#REGRESION PARTES
#crear los tres subconjuntos del DataFrame

DUK1 = DUK.loc[(DUK['Date'] >= '2018-02-12') & (DUK['Date'] <= '2020-01-01')]
DUK2 = DUK.loc[(DUK['Date'] > '2020-01-01') & (DUK['Date'] <= '2022-01-01')]
DUK3 = DUK.loc[(DUK['Date'] > '2022-01-01') & (DUK['Date'] <= '2023-02-10')]

#crear las matrices de características X y la variable objetivo y para cada subconjunto

X1 = pd.to_datetime(DUK1['Date']).apply(lambda x: x.toordinal())
X2 = pd.to_datetime(DUK2['Date']).apply(lambda x: x.toordinal())
X3 = pd.to_datetime(DUK3['Date']).apply(lambda x: x.toordinal())

y1 = DUK1['Adj Close']
y2 = DUK2['Adj Close']
y3 = DUK3['Adj Close']

#ajustar el modelo de regresión lineal para cada subconjunto

model1 = LinearRegression()
model1.fit(X1.values.reshape(-1, 1), y1)

model2 = LinearRegression()
model2.fit(X2.values.reshape(-1, 1), y2)

model3 = LinearRegression()
model3.fit(X3.values.reshape(-1, 1), y3)

#obtener los coeficientes de cada regresión

coef1 = model1.coef_
intercept1 = model1.intercept_

coef2 = model2.coef_
intercept2 = model2.intercept_

coef3 = model3.coef_
intercept3 = model3.intercept_

#graficar las líneas de regresión junto con los puntos originales del DataFrame para cada subconjunto

plt.scatter(pd.to_datetime(DUK1['Date']), y1)
plt.plot(pd.to_datetime(DUK1['Date']), model1.predict(X1.values.reshape(-1, 1)), color='red', label='2018-02-12 to 2020-01-01')

plt.scatter(pd.to_datetime(DUK2['Date']), y2)
plt.plot(pd.to_datetime(DUK2['Date']), model2.predict(X2.values.reshape(-1, 1)), color='green', label='2020-01-01 to 2022-01-01')

plt.scatter(pd.to_datetime(DUK3['Date']), y3)
plt.plot(pd.to_datetime(DUK3['Date']), model3.predict(X3.values.reshape(-1, 1)), color='blue', label='2022-01-01 to 2023-02-10')

plt.xlabel('Date')
plt.ylabel('Adj Close')
plt.title('Regresión lineal en tres partes de DUK')
plt.legend()
plt.show()

# %%
DUK['Date'] = pd.to_datetime(DUK['Date'])

#Obtener la fecha en la que se alcanzó el valor máximo de Adj Close

max_date = DUK.loc[DUK['Adj Close'].idxmax()]['Date']

#Obtener la fecha en la que se alcanzó el valor mínimo de Adj Close

min_date = DUK.loc[DUK['Adj Close'].idxmin()]['Date']

print("Fecha de máximo Adj Close:", max_date)
print("Fecha de mínimo Adj Close:", min_date)
# Out:
# Fecha de máximo Adj Close: 2022-05-27 00:00:00
# Fecha de mínimo Adj Close: 2020-03-23 00:00:00

# %% [markdown]
# # Electricité de France

# %%
EDF = pd.read_csv('EDF.PA.csv')

# %%
#REGRESION  
#crear la matriz de características X y la variable objetivo y

X = pd.to_datetime(EDF['Date']).apply(lambda x: x.toordinal())
y = EDF['Adj Close']

#ajustar el modelo de regresión lineal

model = LinearRegression()
model.fit(X.values.reshape(-1, 1), y)

#obtener los coeficientes de la regresión

coef = model.coef_
intercept = model.intercept_

#graficar la línea de la regresión junto con los puntos originales del DataFrame

plt.scatter(pd.to_datetime(EDF['Date']), y)
plt.plot(pd.to_datetime(EDF['Date']), model.predict(X.values.reshape(-1, 1)), color='red')
plt.xlabel('Date')
plt.ylabel('Adj Close')
plt.title('Regresión lineal EDF')
plt.show()

# %%
#REGRESION PARTES
#crear los tres subconjuntos del DataFrame

EDF1 = EDF.loc[(EDF['Date'] >= '2018-02-12') & (EDF['Date'] <= '2020-01-01')]
EDF2 = EDF.loc[(EDF['Date'] > '2020-01-01') & (EDF['Date'] <= '2022-01-01')]
EDF3 = EDF.loc[(EDF['Date'] > '2022-01-01') & (EDF['Date'] <= '2023-02-10')]

#crear las matrices de características X y la variable objetivo y para cada subconjunto

X1 = pd.to_datetime(EDF1['Date']).apply(lambda x: x.toordinal())
X2 = pd.to_datetime(EDF2['Date']).apply(lambda x: x.toordinal())
X3 = pd.to_datetime(EDF3['Date']).apply(lambda x: x.toordinal())

y1 = EDF1['Adj Close']
y2 = EDF2['Adj Close']
y3 = EDF3['Adj Close']

#ajustar el modelo de regresión lineal para cada subconjunto

model1 = LinearRegression()
model1.fit(X1.values.reshape(-1, 1), y1)

model2 = LinearRegression()
model2.fit(X2.values.reshape(-1, 1), y2)

model3 = LinearRegression()
model3.fit(X3.values.reshape(-1, 1), y3)

#obtener los coeficientes de cada regresión

coef1 = model1.coef_
intercept1 = model1.intercept_

coef2 = model2.coef_
intercept2 = model2.intercept_

coef3 = model3.coef_
intercept3 = model3.intercept_

#graficar las líneas de regresión junto con los puntos originales del DataFrame para cada subconjunto

plt.scatter(pd.to_datetime(EDF1['Date']), y1)
plt.plot(pd.to_datetime(EDF1['Date']), model1.predict(X1.values.reshape(-1, 1)), color='red', label='2018-02-12 to 2020-01-01')

plt.scatter(pd.to_datetime(EDF2['Date']), y2)
plt.plot(pd.to_datetime(EDF2['Date']), model2.predict(X2.values.reshape(-1, 1)), color='green', label='2020-01-01 to 2022-01-01')

plt.scatter(pd.to_datetime(EDF3['Date']), y3)
plt.plot(pd.to_datetime(EDF3['Date']), model3.predict(X3.values.reshape(-1, 1)), color='blue', label='2022-01-01 to 2023-02-10')

plt.xlabel('Date')
plt.ylabel('Adj Close')
plt.title('Regresión lineal en tres partes de EDF')
plt.legend()
plt.show()

# %%
EDF['Date'] = pd.to_datetime(EDF['Date'])

#Obtener la fecha en la que se alcanzó el valor máximo de Adj Close

max_date = EDF.loc[EDF['Adj Close'].idxmax()]['Date']

#Obtener la fecha en la que se alcanzó el valor mínimo de Adj Close

min_date = EDF.loc[EDF['Adj Close'].idxmin()]['Date']

print("Fecha de máximo Adj Close:", max_date)
print("Fecha de mínimo Adj Close:", min_date)
# Out:
# Fecha de máximo Adj Close: 2018-11-08 00:00:00
# Fecha de mínimo Adj Close: 2020-03-19 00:00:00

# %% [markdown]
# # Enel SpA

# %%
ENEL = pd.read_csv('ENEL.MI.csv')

# %%
#REGRESION  
#crear la matriz de características X y la variable objetivo y

X = pd.to_datetime(ENEL['Date']).apply(lambda x: x.toordinal())
y = ENEL['Adj Close']

#ajustar el modelo de regresión lineal

model = LinearRegression()
model.fit(X.values.reshape(-1, 1), y)

#obtener los coeficientes de la regresión

coef = model.coef_
intercept = model.intercept_

#graficar la línea de la regresión junto con los puntos originales del DataFrame

plt.scatter(pd.to_datetime(ENEL['Date']), y)
plt.plot(pd.to_datetime(ENEL['Date']), model.predict(X.values.reshape(-1, 1)), color='red')
plt.xlabel('Date')
plt.ylabel('Adj Close')
plt.title('Regresión lineal ENEL')
plt.show()

# %%
#REGRESION PARTES
#crear los tres subconjuntos del DataFrame

ENEL1 = ENEL.loc[(ENEL['Date'] >= '2018-02-12') & (ENEL['Date'] <= '2020-01-01')]
ENEL2 = ENEL.loc[(ENEL['Date'] > '2020-01-01') & (ENEL['Date'] <= '2022-01-01')]
ENEL3 = ENEL.loc[(ENEL['Date'] > '2022-01-01') & (ENEL['Date'] <= '2023-02-10')]

#crear las matrices de características X y la variable objetivo y para cada subconjunto

X1 = pd.to_datetime(ENEL1['Date']).apply(lambda x: x.toordinal())
X2 = pd.to_datetime(ENEL2['Date']).apply(lambda x: x.toordinal())
X3 = pd.to_datetime(ENEL3['Date']).apply(lambda x: x.toordinal())

y1 = ENEL1['Adj Close']
y2 = ENEL2['Adj Close']
y3 = ENEL3['Adj Close']

#ajustar el modelo de regresión lineal para cada subconjunto

model1 = LinearRegression()
model1.fit(X1.values.reshape(-1, 1), y1)

model2 = LinearRegression()
model2.fit(X2.values.reshape(-1, 1), y2)

model3 = LinearRegression()
model3.fit(X3.values.reshape(-1, 1), y3)

#obtener los coeficientes de cada regresión

coef1 = model1.coef_
intercept1 = model1.intercept_

coef2 = model2.coef_
intercept2 = model2.intercept_

coef3 = model3.coef_
intercept3 = model3.intercept_

#graficar las líneas de regresión junto con los puntos originales del DataFrame para cada subconjunto

plt.scatter(pd.to_datetime(ENEL1['Date']), y1)
plt.plot(pd.to_datetime(ENEL1['Date']), model1.predict(X1.values.reshape(-1, 1)), color='red', label='2018-02-12 to 2020-01-01')

plt.scatter(pd.to_datetime(ENEL2['Date']), y2)
plt.plot(pd.to_datetime(ENEL2['Date']), model2.predict(X2.values.reshape(-1, 1)), color='green', label='2020-01-01 to 2022-01-01')

plt.scatter(pd.to_datetime(ENEL3['Date']), y3)
plt.plot(pd.to_datetime(ENEL3['Date']), model3.predict(X3.values.reshape(-1, 1)), color='blue', label='2022-01-01 to 2023-02-10')

plt.xlabel('Date')
plt.ylabel('Adj Close')
plt.title('Regresión lineal en tres partes de ENEL')
plt.legend()
plt.show()

# %%
ENEL['Date'] = pd.to_datetime(ENEL['Date'])

#Obtener la fecha en la que se alcanzó el valor máximo de Adj Close

max_date = ENEL.loc[ENEL['Adj Close'].idxmax()]['Date']

#Obtener la fecha en la que se alcanzó el valor mínimo de Adj Close

min_date = ENEL.loc[ENEL['Adj Close'].idxmin()]['Date']

print("Fecha de máximo Adj Close:", max_date)
print("Fecha de mínimo Adj Close:", min_date)
# Out:
# Fecha de máximo Adj Close: 2021-01-11 00:00:00
# Fecha de mínimo Adj Close: 2018-09-03 00:00:00

# %% [markdown]
# # Exelon

# %%
EXC = pd.read_csv('EXC.csv')

# %%
#REGRESION  

#crear la matriz de características X y la variable objetivo y

X = pd.to_datetime(EXC['Date']).apply(lambda x: x.toordinal())
y = EXC['Adj Close']

#ajustar el modelo de regresión lineal

model = LinearRegression()
model.fit(X.values.reshape(-1, 1), y)

#obtener los coeficientes de la regresión

coef = model.coef_
intercept = model.intercept_

#graficar la línea de la regresión junto con los puntos originales del DataFrame

plt.scatter(pd.to_datetime(EXC['Date']), y)
plt.plot(pd.to_datetime(EXC['Date']), model.predict(X.values.reshape(-1, 1)), color='red')
plt.xlabel('Date')
plt.ylabel('Adj Close')
plt.title('Regresión lineal EXC')
plt.show()

# %%
#REGRESION PARTES
#crear los tres subconjuntos del DataFrame

EXC1 = EXC.loc[(EXC['Date'] >= '2018-02-12') & (EXC['Date'] <= '2020-01-01')]
EXC2 = EXC.loc[(EXC['Date'] > '2020-01-01') & (EXC['Date'] <= '2022-01-01')]
EXC3 = EXC.loc[(EXC['Date'] > '2022-01-01') & (EXC['Date'] <= '2023-02-10')]

#crear las matrices de características X y la variable objetivo y para cada subconjunto

X1 = pd.to_datetime(EXC1['Date']).apply(lambda x: x.toordinal())
X2 = pd.to_datetime(EXC2['Date']).apply(lambda x: x.toordinal())
X3 = pd.to_datetime(EXC3['Date']).apply(lambda x: x.toordinal())

y1 = EXC1['Adj Close']
y2 = EXC2['Adj Close']
y3 = EXC3['Adj Close']

#ajustar el modelo de regresión lineal para cada subconjunto

model1 = LinearRegression()
model1.fit(X1.values.reshape(-1, 1), y1)

model2 = LinearRegression()
model2.fit(X2.values.reshape(-1, 1), y2)

model3 = LinearRegression()
model3.fit(X3.values.reshape(-1, 1), y3)

#obtener los coeficientes de cada regresión

coef1 = model1.coef_
intercept1 = model1.intercept_

coef2 = model2.coef_
intercept2 = model2.intercept_

coef3 = model3.coef_
intercept3 = model3.intercept_

#graficar las líneas de regresión junto con los puntos originales del DataFrame para cada subconjunto

plt.scatter(pd.to_datetime(EXC1['Date']), y1)
plt.plot(pd.to_datetime(EXC1['Date']), model1.predict(X1.values.reshape(-1, 1)), color='red', label='2018-02-12 to 2020-01-01')

plt.scatter(pd.to_datetime(EXC2['Date']), y2)
plt.plot(pd.to_datetime(EXC2['Date']), model2.predict(X2.values.reshape(-1, 1)), color='green', label='2020-01-01 to 2022-01-01')

plt.scatter(pd.to_datetime(EXC3['Date']), y3)
plt.plot(pd.to_datetime(EXC3['Date']), model3.predict(X3.values.reshape(-1, 1)), color='blue', label='2022-01-01 to 2023-02-10')

plt.xlabel('Date')
plt.ylabel('Adj Close')
plt.title('Regresión lineal en tres partes de EXC')
plt.legend()
plt.show()

# %%
EXC['Date'] = pd.to_datetime(EXC['Date'])

#Obtener la fecha en la que se alcanzó el valor máximo de Adj Close

max_date = EXC.loc[EXC['Adj Close'].idxmax()]['Date']

#Obtener la fecha en la que se alcanzó el valor mínimo de Adj Close

min_date = EXC.loc[EXC['Adj Close'].idxmin()]['Date']

print("Fecha de máximo Adj Close:", max_date)
print("Fecha de mínimo Adj Close:", min_date)
# Out:
# Fecha de máximo Adj Close: 2022-04-20 00:00:00
# Fecha de mínimo Adj Close: 2020-03-23 00:00:00

# %% [markdown]
# # Iberdrola

# %%
IBE = pd.read_csv('IBE.MC.csv')

# %%
IBE.head()
# Out:
#          Date   Open   High    Low  Close  Adj Close      Volume
# 0  2018-02-12  6.020  6.096  5.994  6.086   4.934585  19756048.0
# 1  2018-02-13  6.094  6.100  5.994  5.994   4.859991  14536600.0
# 2  2018-02-14  6.032  6.090  5.982  6.038   4.895665  19025416.0
# 3  2018-02-15  6.072  6.084  5.962  6.046   4.902151  14239437.0
# 4  2018-02-16  6.080  6.142  6.070  6.122   4.963774  32292698.0

# %%
IBE.isnull().sum()
# Out:
# Date         0
# Open         1
# High         1
# Low          1
# Close        1
# Adj Close    1
# Volume       1
# dtype: int64

# %%
IBE['Adj Close'].fillna(IBE['Adj Close'].mean(), inplace=True)

# %%
#REGRESION  
#crear la matriz de características X y la variable objetivo y
X = pd.to_datetime(IBE['Date']).apply(lambda x: x.toordinal())
y = IBE['Adj Close']
#ajustar el modelo de regresión lineal
model = LinearRegression()
model.fit(X.values.reshape(-1, 1), y)
#obtener los coeficientes de la regresión
coef = model.coef_
intercept = model.intercept_
#graficar la línea de la regresión junto con los puntos originales del DataFrame
plt.scatter(pd.to_datetime(IBE['Date']), y)
plt.plot(pd.to_datetime(IBE['Date']), model.predict(X.values.reshape(-1, 1)), color='red')
plt.xlabel('Date')
plt.ylabel('Adj Close')
plt.title('Regresión lineal Intel')
plt.show()

# %% [markdown]
# El puntito volando es el null que rellene con la media

# %%
#REGRESION PARTES
#crear los tres subconjuntos del DataFrame

IBE1 = IBE.loc[(IBE['Date'] >= '2018-02-12') & (IBE['Date'] <= '2020-01-01')]
IBE2 = IBE.loc[(IBE['Date'] > '2020-01-01') & (IBE['Date'] <= '2022-01-01')]
IBE3 = IBE.loc[(IBE['Date'] > '2022-01-01') & (IBE['Date'] <= '2023-02-10')]

#crear las matrices de características X y la variable objetivo y para cada subconjunto

X1 = pd.to_datetime(IBE1['Date']).apply(lambda x: x.toordinal())
X2 = pd.to_datetime(IBE2['Date']).apply(lambda x: x.toordinal())
X3 = pd.to_datetime(IBE3['Date']).apply(lambda x: x.toordinal())

y1 = IBE1['Adj Close']
y2 = IBE2['Adj Close']
y3 = IBE3['Adj Close']

#ajustar el modelo de regresión lineal para cada subconjunto

model1 = LinearRegression()
model1.fit(X1.values.reshape(-1, 1), y1)

model2 = LinearRegression()
model2.fit(X2.values.reshape(-1, 1), y2)

model3 = LinearRegression()
model3.fit(X3.values.reshape(-1, 1), y3)

#obtener los coeficientes de cada regresión

coef1 = model1.coef_
intercept1 = model1.intercept_

coef2 = model2.coef_
intercept2 = model2.intercept_

coef3 = model3.coef_
intercept3 = model3.intercept_

#graficar las líneas de regresión junto con los puntos originales del DataFrame para cada subconjunto

plt.scatter(pd.to_datetime(IBE1['Date']), y1)
plt.plot(pd.to_datetime(IBE1['Date']), model1.predict(X1.values.reshape(-1, 1)), color='red', label='2018-02-12 to 2020-01-01')

plt.scatter(pd.to_datetime(IBE2['Date']), y2)
plt.plot(pd.to_datetime(IBE2['Date']), model2.predict(X2.values.reshape(-1, 1)), color='green', label='2020-01-01 to 2022-01-01')

plt.scatter(pd.to_datetime(IBE3['Date']), y3)
plt.plot(pd.to_datetime(IBE3['Date']), model3.predict(X3.values.reshape(-1, 1)), color='blue', label='2022-01-01 to 2023-02-10')

plt.xlabel('Date')
plt.ylabel('Adj Close')
plt.title('Regresión lineal en tres partes de IBE')
plt.legend()
plt.show()

# %%
IBE['Date'] = pd.to_datetime(IBE['Date'])

#Obtener la fecha en la que se alcanzó el valor máximo de Adj Close

max_date = IBE.loc[IBE['Adj Close'].idxmax()]['Date']

#Obtener la fecha en la que se alcanzó el valor mínimo de Adj Close

min_date = IBE.loc[IBE['Adj Close'].idxmin()]['Date']

print("Fecha de máximo Adj Close:", max_date)
print("Fecha de mínimo Adj Close:", min_date)
# Out:
# Fecha de máximo Adj Close: 2021-01-08 00:00:00
# Fecha de mínimo Adj Close: 2018-03-23 00:00:00

# %% [markdown]
# # NextEra Energy

# %%
NEE = pd.read_csv('NEE.csv')

# %%
#REGRESION  
#crear la matriz de características X y la variable objetivo y

X = pd.to_datetime(NEE['Date']).apply(lambda x: x.toordinal())
y = NEE['Adj Close']

#ajustar el modelo de regresión lineal

model = LinearRegression()
model.fit(X.values.reshape(-1, 1), y)

#obtener los coeficientes de la regresión

coef = model.coef_
intercept = model.intercept_

#graficar la línea de la regresión junto con los puntos originales del DataFrame

plt.scatter(pd.to_datetime(NEE['Date']), y)
plt.plot(pd.to_datetime(NEE['Date']), model.predict(X.values.reshape(-1, 1)), color='red')
plt.xlabel('Date')
plt.ylabel('Adj Close')
plt.title('Regresión lineal NEE')
plt.show()

# %%
#REGRESION PARTES
#crear los tres subconjuntos del DataFrame

NEE1 = NEE.loc[(NEE['Date'] >= '2018-02-12') & (NEE['Date'] <= '2020-01-01')]
NEE2 = NEE.loc[(NEE['Date'] > '2020-01-01') & (NEE['Date'] <= '2022-01-01')]
NEE3 = NEE.loc[(NEE['Date'] > '2022-01-01') & (NEE['Date'] <= '2023-02-10')]

#crear las matrices de características X y la variable objetivo y para cada subconjunto

X1 = pd.to_datetime(NEE1['Date']).apply(lambda x: x.toordinal())
X2 = pd.to_datetime(NEE2['Date']).apply(lambda x: x.toordinal())
X3 = pd.to_datetime(NEE3['Date']).apply(lambda x: x.toordinal())

y1 = NEE1['Adj Close']
y2 = NEE2['Adj Close']
y3 = NEE3['Adj Close']

#ajustar el modelo de regresión lineal para cada subconjunto

model1 = LinearRegression()
model1.fit(X1.values.reshape(-1, 1), y1)

model2 = LinearRegression()
model2.fit(X2.values.reshape(-1, 1), y2)

model3 = LinearRegression()
model3.fit(X3.values.reshape(-1, 1), y3)

#obtener los coeficientes de cada regresión

coef1 = model1.coef_
intercept1 = model1.intercept_

coef2 = model2.coef_
intercept2 = model2.intercept_

coef3 = model3.coef_
intercept3 = model3.intercept_

#graficar las líneas de regresión junto con los puntos originales del DataFrame para cada subconjunto

plt.scatter(pd.to_datetime(NEE1['Date']), y1)
plt.plot(pd.to_datetime(NEE1['Date']), model1.predict(X1.values.reshape(-1, 1)), color='red', label='2018-02-12 to 2020-01-01')

plt.scatter(pd.to_datetime(NEE2['Date']), y2)
plt.plot(pd.to_datetime(NEE2['Date']), model2.predict(X2.values.reshape(-1, 1)), color='green', label='2020-01-01 to 2022-01-01')

plt.scatter(pd.to_datetime(NEE3['Date']), y3)
plt.plot(pd.to_datetime(NEE3['Date']), model3.predict(X3.values.reshape(-1, 1)), color='blue', label='2022-01-01 to 2023-02-10')

plt.xlabel('Date')
plt.ylabel('Adj Close')
plt.title('Regresión lineal en tres partes de NEE')
plt.legend()
plt.show()

# %%
NEE['Date'] = pd.to_datetime(NEE['Date'])

#Obtener la fecha en la que se alcanzó el valor máximo de Adj Close

max_date = NEE.loc[NEE['Adj Close'].idxmax()]['Date']

#Obtener la fecha en la que se alcanzó el valor mínimo de Adj Close

min_date = NEE.loc[NEE['Adj Close'].idxmin()]['Date']

print("Fecha de máximo Adj Close:", max_date)
print("Fecha de mínimo Adj Close:", min_date)
# Out:
# Fecha de máximo Adj Close: 2021-12-31 00:00:00
# Fecha de mínimo Adj Close: 2018-02-12 00:00:00

# %% [markdown]
# # National Grid

# %%
NGG = pd.read_csv('NGG.csv')

# %%
#REGRESION  
#crear la matriz de características X y la variable objetivo y

X = pd.to_datetime(NGG['Date']).apply(lambda x: x.toordinal())
y = NGG['Adj Close']

#ajustar el modelo de regresión lineal

model = LinearRegression()
model.fit(X.values.reshape(-1, 1), y)

#obtener los coeficientes de la regresión

coef = model.coef_
intercept = model.intercept_

#graficar la línea de la regresión junto con los puntos originales del DataFrame

plt.scatter(pd.to_datetime(NGG['Date']), y)
plt.plot(pd.to_datetime(NGG['Date']), model.predict(X.values.reshape(-1, 1)), color='red')
plt.xlabel('Date')
plt.ylabel('Adj Close')
plt.title('Regresión lineal NGG')
plt.show()

# %%
#REGRESION PARTES
#crear los tres subconjuntos del DataFrame

NGG1 = NGG.loc[(NGG['Date'] >= '2018-02-12') & (NGG['Date'] <= '2020-01-01')]
NGG2 = NGG.loc[(NGG['Date'] > '2020-01-01') & (NGG['Date'] <= '2022-01-01')]
NGG3 = NGG.loc[(NGG['Date'] > '2022-01-01') & (NGG['Date'] <= '2023-02-10')]

#crear las matrices de características X y la variable objetivo y para cada subconjunto

X1 = pd.to_datetime(NGG1['Date']).apply(lambda x: x.toordinal())
X2 = pd.to_datetime(NGG2['Date']).apply(lambda x: x.toordinal())
X3 = pd.to_datetime(NGG3['Date']).apply(lambda x: x.toordinal())

y1 = NGG1['Adj Close']
y2 = NGG2['Adj Close']
y3 = NGG3['Adj Close']

#ajustar el modelo de regresión lineal para cada subconjunto

model1 = LinearRegression()
model1.fit(X1.values.reshape(-1, 1), y1)

model2 = LinearRegression()
model2.fit(X2.values.reshape(-1, 1), y2)

model3 = LinearRegression()
model3.fit(X3.values.reshape(-1, 1), y3)

#obtener los coeficientes de cada regresión

coef1 = model1.coef_
intercept1 = model1.intercept_

coef2 = model2.coef_
intercept2 = model2.intercept_

coef3 = model3.coef_
intercept3 = model3.intercept_

#graficar las líneas de regresión junto con los puntos originales del DataFrame para cada subconjunto

plt.scatter(pd.to_datetime(NGG1['Date']), y1)
plt.plot(pd.to_datetime(NGG1['Date']), model1.predict(X1.values.reshape(-1, 1)), color='red', label='2018-02-12 to 2020-01-01')

plt.scatter(pd.to_datetime(NGG2['Date']), y2)
plt.plot(pd.to_datetime(NGG2['Date']), model2.predict(X2.values.reshape(-1, 1)), color='green', label='2020-01-01 to 2022-01-01')

plt.scatter(pd.to_datetime(NGG3['Date']), y3)
plt.plot(pd.to_datetime(NGG3['Date']), model3.predict(X3.values.reshape(-1, 1)), color='blue', label='2022-01-01 to 2023-02-10')

plt.xlabel('Date')
plt.ylabel('Adj Close')
plt.title('Regresión lineal en tres partes de NGG')
plt.legend()
plt.show()

# %%
NGG['Date'] = pd.to_datetime(NGG['Date'])

#Obtener la fecha en la que se alcanzó el valor máximo de Adj Close

max_date = NGG.loc[NGG['Adj Close'].idxmax()]['Date']

#Obtener la fecha en la que se alcanzó el valor mínimo de Adj Close

min_date = NGG.loc[NGG['Adj Close'].idxmin()]['Date']

print("Fecha de máximo Adj Close:", max_date)
print("Fecha de mínimo Adj Close:", min_date)
# Out:
# Fecha de máximo Adj Close: 2022-04-06 00:00:00
# Fecha de mínimo Adj Close: 2018-12-18 00:00:00

# %% [markdown]
# # The Southern Company

# %%
SO = pd.read_csv('SO.csv')

# %%
#REGRESION  
#crear la matriz de características X y la variable objetivo y

X = pd.to_datetime(SO['Date']).apply(lambda x: x.toordinal())
y = SO['Adj Close']

#ajustar el modelo de regresión lineal

model = LinearRegression()
model.fit(X.values.reshape(-1, 1), y)

#obtener los coeficientes de la regresión

coef = model.coef_
intercept = model.intercept_

#graficar la línea de la regresión junto con los puntos originales del DataFrame

plt.scatter(pd.to_datetime(SO['Date']), y)
plt.plot(pd.to_datetime(SO['Date']), model.predict(X.values.reshape(-1, 1)), color='red')
plt.xlabel('Date')
plt.ylabel('Adj Close')
plt.title('Regresión lineal SO')
plt.show()

# %%
#REGRESION PARTES
#crear los tres subconjuntos del DataFrame

SO1 = SO.loc[(SO['Date'] >= '2018-02-12') & (SO['Date'] <= '2020-01-01')]
SO2 = SO.loc[(SO['Date'] > '2020-01-01') & (SO['Date'] <= '2022-01-01')]
SO3 = SO.loc[(SO['Date'] > '2022-01-01') & (SO['Date'] <= '2023-02-10')]

#crear las matrices de características X y la variable objetivo y para cada subconjunto

X1 = pd.to_datetime(SO1['Date']).apply(lambda x: x.toordinal())
X2 = pd.to_datetime(SO2['Date']).apply(lambda x: x.toordinal())
X3 = pd.to_datetime(SO3['Date']).apply(lambda x: x.toordinal())

y1 = SO1['Adj Close']
y2 = SO2['Adj Close']
y3 = SO3['Adj Close']

#ajustar el modelo de regresión lineal para cada subconjunto

model1 = LinearRegression()
model1.fit(X1.values.reshape(-1, 1), y1)

model2 = LinearRegression()
model2.fit(X2.values.reshape(-1, 1), y2)

model3 = LinearRegression()
model3.fit(X3.values.reshape(-1, 1), y3)

#obtener los coeficientes de cada regresión

coef1 = model1.coef_
intercept1 = model1.intercept_

coef2 = model2.coef_
intercept2 = model2.intercept_

coef3 = model3.coef_
intercept3 = model3.intercept_

#graficar las líneas de regresión junto con los puntos originales del DataFrame para cada subconjunto

plt.scatter(pd.to_datetime(SO1['Date']), y1)
plt.plot(pd.to_datetime(SO1['Date']), model1.predict(X1.values.reshape(-1, 1)), color='red', label='2018-02-12 to 2020-01-01')

plt.scatter(pd.to_datetime(SO2['Date']), y2)
plt.plot(pd.to_datetime(SO2['Date']), model2.predict(X2.values.reshape(-1, 1)), color='green', label='2020-01-01 to 2022-01-01')

plt.scatter(pd.to_datetime(SO3['Date']), y3)
plt.plot(pd.to_datetime(SO3['Date']), model3.predict(X3.values.reshape(-1, 1)), color='blue', label='2022-01-01 to 2023-02-10')

plt.xlabel('Date')
plt.ylabel('Adj Close')
plt.title('Regresión lineal en tres partes de SO')
plt.legend()
plt.show()

# %%
SO['Date'] = pd.to_datetime(SO['Date'])

#Obtener la fecha en la que se alcanzó el valor máximo de Adj Close

max_date = SO.loc[SO['Adj Close'].idxmax()]['Date']

#Obtener la fecha en la que se alcanzó el valor mínimo de Adj Close

min_date = SO.loc[SO['Adj Close'].idxmin()]['Date']

print("Fecha de máximo Adj Close:", max_date)
print("Fecha de mínimo Adj Close:", min_date)
# Out:
# Fecha de máximo Adj Close: 2022-08-19 00:00:00
# Fecha de mínimo Adj Close: 2018-02-21 00:00:00

# %% [markdown]
# # China Yangtze Power

# %%
YAN = pd.read_csv('YAN.csv')

# %% [markdown]
# esta en yuans y lo voy a pasar a usd

# %%
YAN['Adj Close'] = YAN['Adj Close']*.15

# %%
#REGRESION  
#crear la matriz de características X y la variable objetivo y

X = pd.to_datetime(YAN['Date']).apply(lambda x: x.toordinal())
y = YAN['Adj Close']

#ajustar el modelo de regresión lineal

model = LinearRegression()
model.fit(X.values.reshape(-1, 1), y)

#obtener los coeficientes de la regresión

coef = model.coef_
intercept = model.intercept_

#graficar la línea de la regresión junto con los puntos originales del DataFrame

plt.scatter(pd.to_datetime(YAN['Date']), y)
plt.plot(pd.to_datetime(YAN['Date']), model.predict(X.values.reshape(-1, 1)), color='red')
plt.xlabel('Date')
plt.ylabel('Adj Close')
plt.title('Regresión lineal YAN')
plt.show()

# %%
#REGRESION PARTES
#crear los tres subconjuntos del DataFrame

YAN1 = YAN.loc[(YAN['Date'] >= '2018-02-12') & (YAN['Date'] <= '2020-01-01')]
YAN2 = YAN.loc[(YAN['Date'] > '2020-01-01') & (YAN['Date'] <= '2022-01-01')]
YAN3 = YAN.loc[(YAN['Date'] > '2022-01-01') & (YAN['Date'] <= '2023-02-10')]

#crear las matrices de características X y la variable objetivo y para cada subconjunto

X1 = pd.to_datetime(YAN1['Date']).apply(lambda x: x.toordinal())
X2 = pd.to_datetime(YAN2['Date']).apply(lambda x: x.toordinal())
X3 = pd.to_datetime(YAN3['Date']).apply(lambda x: x.toordinal())

y1 = YAN1['Adj Close']
y2 = YAN2['Adj Close']
y3 = YAN3['Adj Close']

#ajustar el modelo de regresión lineal para cada subconjunto

model1 = LinearRegression()
model1.fit(X1.values.reshape(-1, 1), y1)

model2 = LinearRegression()
model2.fit(X2.values.reshape(-1, 1), y2)

model3 = LinearRegression()
model3.fit(X3.values.reshape(-1, 1), y3)

#obtener los coeficientes de cada regresión

coef1 = model1.coef_
intercept1 = model1.intercept_

coef2 = model2.coef_
intercept2 = model2.intercept_

coef3 = model3.coef_
intercept3 = model3.intercept_

#graficar las líneas de regresión junto con los puntos originales del DataFrame para cada subconjunto

plt.scatter(pd.to_datetime(YAN1['Date']), y1)
plt.plot(pd.to_datetime(YAN1['Date']), model1.predict(X1.values.reshape(-1, 1)), color='red', label='2018-02-12 to 2020-01-01')

plt.scatter(pd.to_datetime(YAN2['Date']), y2)
plt.plot(pd.to_datetime(YAN2['Date']), model2.predict(X2.values.reshape(-1, 1)), color='green', label='2020-01-01 to 2022-01-01')

plt.scatter(pd.to_datetime(YAN3['Date']), y3)
plt.plot(pd.to_datetime(YAN3['Date']), model3.predict(X3.values.reshape(-1, 1)), color='blue', label='2022-01-01 to 2023-02-10')

plt.xlabel('Date')
plt.ylabel('Adj Close')
plt.title('Regresión lineal en tres partes de YAN')
plt.legend()
plt.show()

# %%
YAN['Date'] = pd.to_datetime(YAN['Date'])

#Obtener la fecha en la que se alcanzó el valor máximo de Adj Close

max_date = YAN.loc[YAN['Adj Close'].idxmax()]['Date']

#Obtener la fecha en la que se alcanzó el valor mínimo de Adj Close

min_date = YAN.loc[YAN['Adj Close'].idxmin()]['Date']

print("Fecha de máximo Adj Close:", max_date)
print("Fecha de mínimo Adj Close:", min_date)
# Out:
# Fecha de máximo Adj Close: 2022-07-19 00:00:00
# Fecha de mínimo Adj Close: 2018-12-06 00:00:00

# %% [markdown]
# # CORRELACION

# %%
energia=pd.DataFrame()
energia["Chang Yangtze Power"]=YAN["Adj Close"]
energia["The Southern Company"]=SO["Adj Close"]
energia["National Grid"]=NGG["Adj Close"]
energia["NextEra Energy"]=NEE["Adj Close"]
energia["Iberdrola"]=IBE["Adj Close"]
energia["Exelon"]=EXC["Adj Close"]
energia["Enel SpA"]=ENEL["Adj Close"]
energia["Electricite de France"]=EDF["Adj Close"]
energia["Duke"]=DUK["Adj Close"]
energia["Brent Crude Oil"]=D["Adj Close"]

# %% [markdown]
# Creando data frame completo de energia

# %%
energia["Sector"]= energia["Chang Yangtze Power"] + energia["The Southern Company"] + energia["National Grid"] + energia["NextEra Energy"] + energia["Iberdrola"] + energia["Exelon"] + energia["Enel SpA"] + energia["Electricite de France"] + energia["Duke"] + energia["Brent Crude Oil"]

# %%
energia["Sector"] = energia["Sector"]*.1

# %%
energia.head()
# Out:
#    Chang Yangtze Power  The Southern Company  National Grid  NextEra Energy  \
# 0            13.002102             35.501301      40.452248       33.323265
# 1            13.135457             35.453617      39.930187       33.560978
# 2            13.327154             34.627266      40.237289       33.341045
# 3            13.427171             35.405949      40.720966       34.307404
# 4            13.543856             35.365696      40.989670       34.667309
#
#    Iberdrola     Exelon  Enel SpA  Electricite de France       Duke  \
# 0   4.934585  22.241854  3.520805               8.442286  61.721870
# 1   4.859991  22.146111  3.495270               8.467261  61.938835
# 2   4.895665  22.106850  3.589900               8.687895  60.653126
# 3   4.902151  22.650465  3.598911               8.433960  61.962299
# 4   4.963774  22.819584  3.649981               8.825268  62.368866
#
#    Brent Crude Oil     Sector
# 0        60.514507  28.365482
# 1        60.361729  28.334944
# ...

# %%
from numpy.lib import shape_base
# Calcular la matriz de correlación
corr_matrix = energia.corr()

# Crear un mapa de calor de la matriz de correlación
sb.heatmap(corr_matrix, cmap='coolwarm', annot=True)

# Mostrar el mapa de calor
plt.show()

# %% [markdown]
# Creando data frame de tecnología

# %%
from google.colab import files
import io as io
upload=files.upload()
# Out:
#      <input type="file" id="files-a075129d-629e-4b97-b72f-32c5236d01c0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a075129d-629e-4b97-b72f-32c5236d01c0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
apple = pd.read_csv('AAPL.csv')
samsung = pd.read_csv('Alphabet.csv')
alphabet = pd.read_csv('IBM.csv')
msft = pd.read_csv('INTC.csv')
ibm = pd.read_csv('META.csv')
intc = pd.read_csv('MSFT.csv')
META = pd.read_csv('ORCL.csv')
ORCL = pd.read_csv('TSM.csv')
TCEHY = pd.read_csv('Samsung.csv')
TSM = pd.read_csv('TCEHY.csv')

# %%
tec=pd.DataFrame()
tec["Apple"]=apple["Adj Close"]
tec["Samsung"]=samsung["Adj Close"]
tec["Alphabet"]=alphabet["Adj Close"]
tec["Microsoft"]=msft["Adj Close"]
tec["IBM"]=ibm["Adj Close"]
tec["Intel"]=intc["Adj Close"]
tec["Meta"]=META["Adj Close"]
tec["Oracle"]=ORCL["Adj Close"]
tec["TCEHY"]=TCEHY["Adj Close"]*.001
tec["TSM"]=TSM["Adj Close"]

# %%
tec["Sector"]=tec["Apple"]+tec["Samsung"]+tec["Alphabet"]+tec["Microsoft"]+tec["IBM"]+tec["Intel"]+tec["Meta"]+tec["Oracle"]+tec["TCEHY"]+tec["TSM"]

# %%
tec["Sector"] = tec["Sector"]*.1

# %%
tec.head()
# Out:
#        Apple    Samsung    Alphabet  Microsoft         IBM      Intel  \
# 0  38.778717  52.597000  113.618546  38.820560  176.410004  83.725319
# 1  39.167202  52.605000  113.130722  38.500153  173.149994  84.382896
# 2  39.889332  53.485001  116.140076  39.296825  179.520004  85.704170
# 3  41.228760  54.476002  117.078133  39.764435  179.960007  87.450172
# 4  41.095284  54.740002  117.205688  39.452698  177.360001  86.827263
#
#         Meta     Oracle      TCEHY        TSM     Sector
# 0  44.330383  36.581379  39.424047  32.338898  65.662485
# 1  44.643421  36.452358  40.993422  32.183697  65.520886
# 2  45.527256  37.028648  42.252367  32.559444  67.140312
# 3  46.622849  37.432915  41.717750  32.445087  67.817611
# 4  46.687305  37.398499  40.872703  32.600285  67.423973

# %%
from numpy.lib import shape_base
# Calcular la matriz de correlación
corr_matrix = tec.corr()

# Crear un mapa de calor de la matriz de correlación
sb.heatmap(corr_matrix, cmap='coolwarm', annot=True)

# Mostrar el mapa de calor
plt.show()

# %% [markdown]
# Creando data frame de farmaceuticas

# %%
ABBV = pd.read_csv('ABBV.csv')
ABT = pd.read_csv('ABT.csv')
BAYRY = pd.read_csv('BAYRY.csv')
GSK = pd.read_csv('GSK.csv')
JNJ = pd.read_csv('JNJ.csv')
MRK = pd.read_csv('MRK.csv')
NVS = pd.read_csv('NVS.csv')
PFE = pd.read_csv('PFE.csv')
RHHBY = pd.read_csv("RHHBY.csv")
SNY = pd.read_csv('SNY.csv')

# %%
farma=pd.DataFrame()
farma["Roche"]=RHHBY["Adj Close"]
farma["Bayer"]=BAYRY["Adj Close"]
farma["Pfizer"]=PFE["Adj Close"]
farma["Abbott"]=ABT["Adj Close"]
farma["Merck"]=MRK["Adj Close"]
farma["GlaxoSmithKline"]=GSK["Adj Close"]
farma["Johnson & Johnson"]=JNJ["Adj Close"]
farma["Novartis"]=NVS["Adj Close"]
farma["AbbVie"]=ABBV["Adj Close"]
farma["Sanofi"]=SNY["Adj Close"]

# %%
farma["Sector"] = farma["Roche"] + farma["Bayer"] + farma["Pfizer"] + farma["Abbott"] + farma["Merck"] + farma["GlaxoSmithKline"] + farma["Johnson & Johnson"] + farma["Novartis"] + farma["AbbVie"] + farma["Sanofi"]

# %%
farma["Sector"] = farma["Sector"]*.1

# %%
from numpy.lib import shape_base
# Calcular la matriz de correlación
corr_matrix = farma.corr()

# Crear un mapa de calor de la matriz de correlación
sb.heatmap(corr_matrix, cmap='coolwarm', annot=True)

# Mostrar el mapa de calor
plt.show()

# %% [markdown]
# Correlacion del sector de todas

# %%
juntas=pd.DataFrame()

# %%
juntas["tec"] = tec["Promedio"]
juntas["farma"] = farma["Promedio"]
juntas["energia"] = energia["Promedio"]

# %%
from numpy.lib import shape_base
# Calcular la matriz de correlación
corr_matrix = juntas.corr()

# Crear un mapa de calor de la matriz de correlación
sb.heatmap(corr_matrix, cmap='coolwarm', annot=True)

# Mostrar el mapa de calor
plt.show()
